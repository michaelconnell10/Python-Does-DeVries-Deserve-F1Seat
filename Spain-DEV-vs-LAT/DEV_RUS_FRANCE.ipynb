# %%
import fastf1
from fastf1 import plotting
from matplotlib import pyplot as plt

plotting.setup_mpl()

race = fastf1.get_session(2022, 'French Grand Prix', 'FP1')
race.load()

dev = race.laps.pick_driver('DEV')
rus = race.laps.pick_driver('RUS')

fig, ax = plt.subplots()
fig.set_figwidth(15)
ax.plot(dev['LapNumber'], dev['LapTime'], color='red')
ax.plot(rus['LapNumber'], rus['LapTime'], color='cyan')
ax.set_title("DEV vs RUS")
ax.set_xlabel("Lap Number")
ax.set_ylabel("Lap Time")

plt.show()
# Out:
# core           INFO 	Loading data for French Grand Prix - Practice 1 [v2.3.0]
# api            INFO 	Fetching driver list...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Fetching timing app data...
# core           INFO 	Processing timing data...
# api            INFO 	Fetching session status data...
# api            INFO 	Fetching track status data...
# api            INFO 	Fetching car data...
# api            INFO 	Parsing car data...
# api            INFO 	Fetching position data...
# api            INFO 	Parsing position data...
# api            INFO 	Fetching weather data...
# api            INFO 	Fetching race control messages...
# core           INFO 	Finished loading data for 20 drivers: ['1', '55', '47', '31', '24', '23', '22', '20', '19', '18', '16', '14', '11', '10', '6', '5', '4', '3', '63', '88']

# %%
dev_lap = session.laps.pick_driver('DEV').pick_fastest()
rus_lap = session.laps.pick_driver('RUS').pick_fastest()

dev_tel = dev_lap.get_car_data().add_distance()
rus_tel = rus_lap.get_car_data().add_distance()

fig, ax = plt.subplots()
fig.set_figwidth(15)
ax.plot(dev_tel['Distance'], dev_tel['Speed'], color='red', label='DEV')
ax.plot(lat_tel['Distance'], rus_tel['Speed'], color='cyan', label='RUS')

ax.set_xlabel('Distance in m')
ax.set_ylabel('Speed in km/h')

ax.legend()
plt.suptitle(f"Fastest Lap Comparison \n "
             f"{session.event['EventName']} {session.event.year} Practice 1")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 dev_lap = session.laps.pick_driver('DEV').pick_fastest()
#       2 rus_lap = session.laps.pick_driver('RUS').pick_fastest()
#       4 dev_tel = dev_lap.get_car_data().add_distance()
#
# NameError: name 'session' is not defined
